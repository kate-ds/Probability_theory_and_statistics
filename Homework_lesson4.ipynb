# %%
import math as m
from sympy import *
import warnings

# %% [markdown]
# ---
# __1__ Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800].
# Найдите ее среднее значение и дисперсию.
#
# ---
#
# Для равномерного распределения:
# $$M(x) = \frac{a + b}{2}$$
# $$D(x) = \frac{(b - a)^2}{12}$$

# %%
a = 200
b = 800
m_x = (a + b) /2
d_x = (b - a)**2 / 12
print("M(x) = ", m_x, "\nD(x) = ", d_x)
# Out:
# M(x) =  500.0
# D(x) =  30000.0

# %% [markdown]
# ---
# __2.__ О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2.
# Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5?
# Если да, найдите ее.
#
# ---
#
# Можно найти из формулы нахождения дисперсии $$D(x) = \frac{(b - a)^2}{12} \Rightarrow b = \sqrt{12D(x)} + a$$

# %%
d_x = 0.2
a = 0.5
b = m.sqrt(12 * d_x) + a
m_x = (a + b) /2
print("b = ", b, "\nM(x) = ", m_x)
# Out:
# b =  2.049193338482967
# M(x) =  1.2745966692414834

# %%
warnings.filterwarnings('ignore')

init_printing()
b = Symbol('b')
f = (b-0.5)**2 / 12 - 0.2
solve([f, b > 0])
# Out:
# b = 2.04919333848297

# %% [markdown]
# ---
# __3.__ Непрерывная случайная величина X распределена нормально и задана плотностью распределения
#
# $$f(x) = \frac{1}{4 \sqrt{2\pi}} \cdot e^{-\frac{(x+2)^2}{32}}$$
# Найдите:
# а). M(X)
# б). D(X)
# в). std(X) (среднее квадратичное отклонение)
#
# ---
#
# Распределение соответствует функции нормального распределения $$f(x) = \frac{1}{\sigma \sqrt{2\pi}} \cdot e^{-\frac{(x-a)^2}{2 \cdot \sigma^2}}$$ где $\sigma^2$ - дисперсия D(x), $a = M(x)$
#
# Соответственно, $M(X) = -2$, $D(X) = \frac{32}{2} = 16$, $std(X) = \sigma = 4$

# %% [markdown]
# ---
# __4.__ Рост взрослого населения города X имеет нормальное распределение.
# Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см.
# Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# а). больше 182 см
# б). больше 190 см
# в). от 166 см до 190 см
# г). от 166 см до 182 см
# д). от 158 см до 190 см
# е). не выше 150 см или не ниже 190 см
# ё). не выше 150 см или не ниже 198 см
# ж). ниже 166 см.
#
# ---

# %% [markdown]
# __a)__ больше 182

# %%
x = 182
m_x = 174
std_x = 8 
Z = (x - m_x) / std_x
Z
# Out:
# 1.0

# %%
# по таблице накопленного нормального распределения P(1.0) = 0,8413
p_182 = 0.8413
p = 1 - p_182 # или P(-Z) = 0.1587
p
# Out:
# 0.15869999999999995

# %% [markdown]
# __б)__ больше 190

# %%
x = 190
m_x = 174
std_x = 8 
Z = (x - m_x) / std_x
Z
# Out:
# 2.0

# %%
# по таблице накопленного нормального распределения P(2.0) = 0,9772
p_190 = 0.9772
p = 1 - p_190 # или P(-Z) = 0.0228
p
# Out:
# 0.022800000000000042

# %% [markdown]
# __в)__ от 166 см до 190 см

# %%
x_a = 166
x_b = 190
z_a = Z = (x_a - m_x) / std_x
z_b = Z = (x_b - m_x) / std_x
print('Z_a = ', z_a, '\nZ_b = ', z_b)
# Out:
# Z_a =  -1.0
# Z_b =  2.0

# %%
# по таблице накопленного нормального распределения P(2.0) = 0,9772, P(-1) = 0.1587
p_166 = 0.1587
p_190 = 0.9772
p = p_190 - p_166
print ('P(166 < X < 190) = ', p)
# Out:
# P(166 < X < 190) =  0.8185

# %% [markdown]
# __г)__ от 166 см до 182 см -
#
# 1) Вероятность того, что случайная величина находится в интервале от $-\sigma$ до $+\sigma$ примерно равна 68%
#
# 2) По таблицам:
#
# P(X < 182) = 0.8413
# P(X < 166) = 0.1587
# P(166 < X < 182) = 0.8413 - 0.1587 = 0,6826

# %%
p =  p_182 - p_166
print ('P(166 < X < 182) = ', p)
# Out:
# P(166 < X < 182) =  0.6826000000000001

# %% [markdown]
# __д)__ от 158 см до 190 см

# %%
x_a = 158
x_b = 190
z_a = Z = (x_a - m_x) / std_x
z_b = Z = (x_b - m_x) / std_x
print('Z_a = ', z_a, '\nZ_b = ', z_b)
# Out:
# Z_a =  -2.0
# Z_b =  2.0

# %% [markdown]
# 1) Вероятность того, что случайная величина находится в интервале от $-2\sigma$ до $+2\sigma$ примерно равна 95,4%
#
# 2) По таблице накопленного нормального распределения P(2.0) = 0,9772, P(-2) = 0.0228

# %%
p_158 = 0.0228
p = p_190 - p_158
print ('P(158 < X < 182) = ', p)
# Out:
# P(158 < X < 182) =  0.9543999999999999

# %% [markdown]
# __е)__ не выше 150 см или не ниже 190 см

# %%
x_a = 150
x_b = 190
z_a = Z = (x_a - m_x) / std_x
z_b = Z = (x_b - m_x) / std_x
print('Z_a = ', z_a, '\nZ_b = ', z_b)
# Out:
# Z_a =  -3.0
# Z_b =  2.0

# %%
# По таблице накопленного нормального распределения P(2.0) = 0,9772, P(-3) = 0.0014

# %%
p_150 = 0.0014
p = p_150 + (1 - p_190)
print ('(X < 150) V  X > 190) = ', p)
# Out:
# (X < 150) V  X > 190) =  0.02420000000000004

# %% [markdown]
# __ё)__ не выше 150 см или не ниже 198 см

# %%
x_a = 150
x_b = 198
z_a = Z = (x_a - m_x) / std_x
z_b = Z = (x_b - m_x) / std_x
print('Z_a = ', z_a, '\nZ_b = ', z_b)
# Out:
# Z_a =  -3.0
# Z_b =  3.0

# %%
# По таблице накопленного нормального распределения P(3.0) = 0,9986, P(-3.0) = 0.0014
p_198 = 0.9986
p = p_150 + (1 - p_198)
print ('(X < 150) V  X > 199) = ', p)
# Out:
# (X < 150) V  X > 199) =  0.002799999999999957

# %% [markdown]
# __ж)__ ниже 166 см

# %%
p_166 # посчитано выше
# Out:
# 0.1587

# %% [markdown]
# ---
# __5.__ На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от
# математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?
#
# ---

# %%
d_x = 25
std_x = m.sqrt(25)
z = (190 - 178) / std_x
print(z)
# Out:
# 2.4
